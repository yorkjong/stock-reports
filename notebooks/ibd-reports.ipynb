# %% [markdown]
# <a href="https://colab.research.google.com/github/yorkjong/stock-reports/blob/main/notebooks/ibd-reports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Instal and Setup (免費版Colab會固定時間清掉安裝的東西，所以重安裝是新連線後最先要做的事)

# %% [markdown]
# #### Install Packages

# %%
# %pip install "git+https://github.com/yorkjong/vistock.git@feature/ibd"
# %pip install requests-cache
# Out:
# Collecting git+https://github.com/yorkjong/vistock.git@feature/ibd
#   Cloning https://github.com/yorkjong/vistock.git (to revision feature/ibd) to /tmp/pip-req-build-2llb9fqi
#   Running command git clone --filter=blob:none --quiet https://github.com/yorkjong/vistock.git /tmp/pip-req-build-2llb9fqi
#   Running command git checkout -b feature/ibd --track origin/feature/ibd
#   Switched to a new branch 'feature/ibd'
#   Branch 'feature/ibd' set up to track remote branch 'feature/ibd' from 'origin'.
#   Resolved https://github.com/yorkjong/vistock.git to commit 3eea67d171604c08e10fee2b33e9a77fb71fc69f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from vistock==0.4.0) (2.1.4)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (from vistock==0.4.0) (0.2.41)
# Collecting mplfinance (from vistock==0.4.0)
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from vistock==0.4.0) (5.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vistock==0.4.0) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from vistock==0.4.0) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->vistock==0.4.0) (2.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mplfinance->vistock==0.4.0) (3.7.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.4.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.4.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.4.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->vistock==0.4.0) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->vistock==0.4.0) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly->vistock==0.4.0) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.4.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.4.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.4.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vistock==0.4.0) (2024.7.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.4.0) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.4.0) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.4.0) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.4.0) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.4.0) (3.17.6)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance->vistock==0.4.0) (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance->vistock==0.4.0) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance->vistock==0.4.0) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.4.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.4.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.4.0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.4.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mplfinance->vistock==0.4.0) (3.1.2)
# Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.0 MB/s eta 0:00:00
# Building wheels for collected packages: vistock
#   Building wheel for vistock (setup.py) ... done
#   Created wheel for vistock: filename=vistock-0.4.0-py3-none-any.whl size=42114 sha256=7f79dc0c1a6127b9fecf2521dacff58f1db74459736359bc3723e8c0b915aa7d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nefx_2ez/wheels/3e/1c/74/97ec620813c1bb106679625869f7409ca5be8735d0a74457bf
# Successfully built vistock
# Installing collected packages: mplfinance, vistock
# Successfully installed mplfinance-0.12.10b0 vistock-0.4.0
# Collecting requests-cache
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (24.2.0)
# Collecting cattrs>=22.2 (from requests-cache)
#   Downloading cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (4.2.2)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (2.32.3)
# Collecting url-normalize>=1.4 (from requests-cache)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache) (2.0.7)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22->requests-cache) (2024.7.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache) (1.16.0)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.4 MB/s eta 0:00:00
# Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.3 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache
# Successfully installed cattrs-23.2.3 requests-cache-1.2.1 url-normalize-1.4.3

# %%
# @title Install Cache
import requests_cache
requests_cache.install_cache('ibd_cache', expire_after=3600)

# %% [markdown]
# #### Setup and Configuration

# %%
# @title Enable Requests Cache
import requests_cache
requests_cache.install_cache('ibd_cache', expire_after=3600)

# %%
# @title ReadOnlyGitHub
import requests
import pandas as pd
from io import StringIO

class ReadOnlyGitHub:
    def __init__(self, repo_owner, repo_name, dir='', branch='main'):
        dir = dir.strip('/')
        base = 'https://raw.githubusercontent.com'
        if dir:
            self.raw_url = f'{base}/{repo_owner}/{repo_name}/{branch}/{dir}'
        else:
            self.raw_url = f'{base}/{repo_owner}/{repo_name}/{branch}'

        base = 'https://api.github.com/repos'
        if dir:
            self.api_url = f'{base}/{repo_owner}/{repo_name}/contents/{dir}'
        else:
            self.api_url = f'{base}/{repo_owner}/{repo_name}/contents'

    def file_exists(self, file_path):
        url = f'{self.raw_url}/{file_path}'
        response = requests.head(url)
        return response.status_code == 200

    def list_filenames(self, dir_path=''):
        url = f'{self.api_url}/{dir_path}'
        response = requests.get(url)
        if response.status_code == 200:
            files = response.json()
            return [item['name'] for item in files]
        else:
            print(f"Request failed: {response.status_code} - {response.text}")
            return []

    def download_csv(self, file_path):
        url = f'{self.raw_url}/{file_path}'
        if self.file_exists(file_path):
            return pd.read_csv(url)
        else:
            return pd.DataFrame()

# Create a GitHub instance
github = ReadOnlyGitHub(
    repo_owner='yorkjong',
    repo_name='stock-reports',
    dir='ibd'
)

# %%
# @title DataFrame Operations
import vistock.tw as tw

def add_name_column(df):
    column_names = df.columns.tolist()
    if 'Name' in column_names:
        return df
    if 'Ticker' not in column_names:
        return df
    ticker = df['Ticker'].iloc[0].replace('.TWO', '').replace('.TW', '')
    if not ticker.isdigit():
        return df
    df['Name'] = None
    ticker_index = column_names.index('Ticker')
    column_names.insert(ticker_index + 1, 'Name')
    df = df[column_names]
    df['Name'] = df['Ticker'].apply(tw.stock_name)
    return df


def filter_increasing_relative_strength(df):
    """
    Filter stocks with increasing Relative Strength over different time periods.

    This function filters the DataFrame to include only those stocks where:
    - Relative Strength is above 100.
    - Relative Strength has increased over the past 1 month, 3 months, and 6 months.
    Optionally, you can add a condition to check if Percentile is above 90.
    """
    return df[
        (df["Relative Strength"] > 100)
        & (df["Relative Strength"] > df["1 Month Ago"])
        & (df["1 Month Ago"] > df["3 Months Ago"])
        & (df["3 Months Ago"] > df["6 Months Ago"])
        # & (df["Percentile"] > 90)  # Uncomment to include Percentile filter
    ]

# %% [markdown]
# ### Glossary of Terms

# %% [markdown]
# source (Select the source of stocks to analyze):
# - The source of stocks to analyze
# - This could include stocks traded on exchanges or components of a specific index.
# - Common abbreviation(s) for the exchange or market sector.
#   - For Taiwan Markets, possible values include:
#     - `TWSE`: Taiwan Stock Exchange
#     - `TPEX`: Taipei Exchange
#     - `ESB`: Emerging Stock Board
#   - Can also be combined with '+' (e.g., `TWSE+TPEX`, `TWSE+TPEX+ESB`)
#   - For America Markets, possible values include:
#     - `SPX`: S&P 500
#     - `DJIA`: Dow Jones Industrial Average
#     - `NDX`: NASDAQ-100
#     - `SOX`: PHLX Semiconductor Index
#   - Multiple indices can be combined using '+' (e.g., `SPX+DJIA+NDX+SOX`)
#
# period (Historical Data Time Range)：
# - The time range for which to fetch historical data.
# - `2y` means 2 years
# - `6mo` means 6 monthes

# %% [markdown]
# ### Execute Actions Step by Step

# %%
# @title Step 1. Pick a File

import ipywidgets as widgets
from IPython.display import display

# List of filenames
filenames = github.list_filenames()

# Extract and sort all unique values
dates = sorted(set(fn.split('_')[3].replace('.csv', '') for fn in filenames), reverse=True)
sources = sorted(set(fn.split('_')[0] for fn in filenames), reverse=True)
types = sorted(set(fn.split('_')[1] for fn in filenames), reverse=True)
periods = sorted(set(fn.split('_')[2] for fn in filenames), reverse=True)

# Calculate the maximum length of filenames for setting dropdown width
max_filename_length = max(len(fn) for fn in filenames)
dropdown_width = f'{max_filename_length * 10}px'  # 10px per character for width

# Create dropdowns with dynamic width
date_dropdown = widgets.Dropdown(
    options=dates,
    description='Date:',
    layout=widgets.Layout(width=dropdown_width)
)

source_dropdown = widgets.Dropdown(
    options=sources,
    description='Source:',
    layout=widgets.Layout(width=dropdown_width)
)

type_dropdown = widgets.Dropdown(
    options=types,
    description='Type:',
    layout=widgets.Layout(width=dropdown_width)
)

period_dropdown = widgets.Dropdown(
    options=periods,
    description='Period:',
    layout=widgets.Layout(width=dropdown_width)
)

# Create the file selection dropdown
file_dropdown = widgets.Dropdown(
    options=[],
    description='File:',
    layout=widgets.Layout(width=dropdown_width)
)

# Function to update file options based on selected filters
def update_file_options(*args):
    filtered_files = [
        fn for fn in filenames
        if (date_dropdown.value in fn and
            source_dropdown.value in fn and
            type_dropdown.value in fn and
            period_dropdown.value in fn)
    ]
    file_dropdown.options = filtered_files
    if filtered_files:
        file_dropdown.value = filtered_files[0]  # Set initial value to the first match

# Function to handle file selection and print the selected filename
#def on_file_selected(change):
#    selected_file = change['new']
#    print(f"Selected file: {selected_file}")

# Update file options when any of the dropdowns change
date_dropdown.observe(update_file_options, 'value')
source_dropdown.observe(update_file_options, 'value')
type_dropdown.observe(update_file_options, 'value')
period_dropdown.observe(update_file_options, 'value')

# Print the selected file when it changes
#file_dropdown.observe(on_file_selected, 'value')

# Display all dropdowns
display(date_dropdown, source_dropdown, type_dropdown, period_dropdown, file_dropdown)

# Initialize the file dropdown with options
update_file_options()
# Out:
# Dropdown(description='Date:', layout=Layout(width='430px'), options=('20240811', '20240809'), value='20240811'…
# Dropdown(description='Source:', layout=Layout(width='430px'), options=('TWSE+TPEX', 'SPX+DJIA+NDX+SOX'), value…
# Dropdown(description='Type:', layout=Layout(width='430px'), options=('stocks', 'industries'), value='stocks')
# Dropdown(description='Period:', layout=Layout(width='430px'), options=('2y',), value='2y')
# Dropdown(description='File:', layout=Layout(width='430px'), options=(), value=None)

# %%
# @title Step 2. Print Top Percentile Items {"run":"auto"}
num_items = 10 # @param [10, 20, 30] {"type":"raw"}

selected_file = file_dropdown.value
source, kind, period, date = selected_file.split('_')
date.replace('.csv', '')
print(f"Source: {source}\nType: {kind}\nPeriod: {period}\nDate: {date}")

df = github.download_csv(selected_file)
df_top = df.head(num_items).copy()
df_top = add_name_column(df_top)
display(df_top)

print(list(df_top['Name']))
print(list(df_top['Ticker']))
# Out:
# Source: TWSE+TPEX
# Type: stocks
# Period: 2y
# Date: 20240811.csv
#   Ticker Name                  Sector  \
# 0   1799   易威              Healthcare
# 1   6144  得利影  Communication Services
# 2   8374   羅昇             Industrials
# 3   2365   昆盈              Technology
# 4   4562   穎漢             Industrials
# 5   6640   均華              Technology
# 6   6442   光聖              Technology
# 7   3535  晶彩科              Technology
# 8   2543   皇昌             Industrials
# 9   4909  新復興              Technology
#
#                                    Industry  Relative Strength  1 Month Ago  \
# 0  Drug Manufacturers - Specialty & Generic             449.01       367.67
# 1                             Entertainment             414.66       257.19
# 2                   Industrial Distribution             381.67       259.81
# 3                         Computer Hardware             363.02       291.75
# 4            Specialty Industrial Machinery             352.39       302.62
# 5                            Semiconductors             331.40       309.49
# 6                     Electronic Components             308.21       445.17
# 7                         Computer Hardware             302.40       284.42
# 8                Engineering & Construction             301.18       286.28
# 9                     Electronic Components             292.21       247.98
#
#    3 Months Ago  6 Months Ago  Percentile   1 Month Ago   3 Months Ago  \
# 0        204.37        196.92          99            99             98
# 1        116.92         83.50          99            99             87
# 2         83.37         82.81          99            99             41
# 3        137.61        191.30          99            99             94
# 4        159.95         83.68          99            99             96
# 5        236.10        167.45          99            99             99
# 6        194.32        146.70          99            99             98
# 7         95.31        110.10          99            99             66
# 8        296.68        231.43          99            99             99
# 9        247.04        224.91          99            99             99
#
#     6 Months Ago  Rank
# 0             98     1
# 1             18     2
# 2             16     3
# 3             98     4
# 4             19     5
# 5             96     6
# 6             94     7
# 7             78     8
# 8             99     9
# 9             99    10
# ['易威', '得利影', '羅昇', '昆盈', '穎漢', '均華', '光聖', '晶彩科', '皇昌', '新復興']
# ['1799', '6144', '8374', '2365', '4562', '6640', '6442', '3535', '2543', '4909']

# %%
# @title Step 3. Filter Items with Increasing RS > 100
num_items = 10 # @param [10, 20, 30] {"type":"raw"}

selected_file = file_dropdown.value
source, kind, period, date = selected_file.split('_')
date.replace('.csv', '')
print(f"Source: {source}\nType: {kind}\nPeriod: {period}\nDate: {date}")

df = github.download_csv(selected_file)
filtered_df = filter_increasing_relative_strength(df)
df_top = filtered_df.head(num_items).copy()
df_top = add_name_column(df_top)
display(df_top)

print(list(df_top['Name']))
print(list(df_top['Ticker']))
# Out:
# Source: TWSE+TPEX
# Type: stocks
# Period: 2y
# Date: 20240811.csv
#    Ticker Name                  Sector  \
# 0    1799   易威              Healthcare
# 1    6144  得利影  Communication Services
# 2    8374   羅昇             Industrials
# 4    4562   穎漢             Industrials
# 5    6640   均華              Technology
# 9    4909  新復興              Technology
# 13   2348   海悅             Real Estate
# 14   9906  欣巴巴             Industrials
# 17   2524   京城             Real Estate
# 23   1225  福懋油      Consumer Defensive
#
#                                     Industry  Relative Strength  1 Month Ago  \
# 0   Drug Manufacturers - Specialty & Generic             449.01       367.67
# 1                              Entertainment             414.66       257.19
# 2                    Industrial Distribution             381.67       259.81
# 4             Specialty Industrial Machinery             352.39       302.62
# 5                             Semiconductors             331.40       309.49
# 9                      Electronic Components             292.21       247.98
# 13                      Real Estate Services             275.40       215.50
# 14                Engineering & Construction             264.48       157.31
# 17                   Real Estate—Development             246.44       151.31
# 23                            Packaged Foods             224.83       185.03
#
#     3 Months Ago  6 Months Ago  Percentile   1 Month Ago   3 Months Ago  \
# 0         204.37        196.92          99            99             98
# 1         116.92         83.50          99            99             87
# 2          83.37         82.81          99            99             41
# 4         159.95         83.68          99            99             96
# 5         236.10        167.45          99            99             99
# 9         247.04        224.91          99            99             99
# 13        211.95        122.17          99            98             99
# 14        123.81        115.12          99            96             90
# 17        138.69         87.36          99            96             94
# 23        101.59         88.83          98            98             75
#
#      6 Months Ago  Rank
# 0              98     1
# 1              18     2
# 2              16     3
# 4              19     5
# 5              96     6
# 9              99    10
# 13             86    14
# 14             82    15
# 17             30    18
# 23             36    24
# ['易威', '得利影', '羅昇', '穎漢', '均華', '新復興', '海悅', '欣巴巴', '京城', '福懋油']
# ['1799', '6144', '8374', '4562', '6640', '4909', '2348', '9906', '2524', '1225']
